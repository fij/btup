# %% [markdown]
# ## Spring 2024

# %% [markdown]
# ### May-06
#
# 1. How is the instantaneous forward rate related to the discount factor ?
#
# 2. The 3Y simple rate is 5.5\%. The 1Y$\rightarrow$3Y fwd rate is 5.8\%. What is the 1Y discount factor?
#
# 3. For a group of 100 companies the hazard rate is a constant 1\%. How many of them do you expect to default within 3 years ?
#
# 4. The `bond yield` is that particular ZC rate that makes the net sum of the PVs of the bond's future cash flows equal to the bond's current market price. The bond's `PV01` (present value of 1 basis point) is its price change after its 1bp yield change. What is the `sign` of PV01 ?
#
# 5. Please define the general form of the Ito process and explain the special case of the mean-reverting process.
#
# 6. Please explain a proof of the put-call parity.
#
# 7. If a call option has no associated costs (taxes, transaction costs), then what should be the net sum of its upfront fee and the PV of its expected payoff ?
#
# 8. How is the Lagrange method applied during the derivation of the MPT ?
#
# 9. How is risk quantified in the theory of efficient markets (MPT and CAPM) ?
#
# 10. What is the difference between the Treynor ratio and the Sharpe ratio ?
#
# 11. What free parameters are used in the binomial tree pricer model and how are these free parameters eliminated ?
#
# 12. Please write down the two terms of the Black-Scholes price of a european call option on a non-dividend-paying underlying stock and explain these two terms.

# %% [markdown]
# ### Apr-29
#
# 1. What is a Markov process ? Please give a very simple example.
# <br/>
#
# 2. What is the general form of the Ito process ?
# <br/>
#
# 3. Please explain a mean-reverting process with non-zero mean.
# <br/>
#
# 4. Assume that the function $\,f\left(\,t\,\right)\,$ is an Ito process with $\,\mu=5\%\,$ and $\,\sigma=1\%\,$. What can you say about $\,f\left(\,1\,\right)\,$ ?
# <br/>
#
# 5. What is the difference between the spot rate and the short rate ?
# <br/>
#
# 6. The 2Y discount factor is $\,0.6\,$. The 1Y simple rate is $\,20\%\,$. What is the 1Y$\rightarrow$2Y fwd rate ?
# <br/>
#
# 7. What is the difference between the Sharpe ratio and the Sortino ratio ?
# <br/>
#
# 8. With 1 put and 1 call, please construct a payoff function that is 0 between -1 and +1, and linearly growing outside.
# <br/>
#
# 9. What is the main characteristic of most commodities ? How do precious metals differ ?
# <br/>
#
# 10. What were the key steps during the derivation of the differential form of the Ito process ?

# %% [markdown]
# ### Apr-22
#
# 1. What is a martingale process ? Please give a very simple example.
# <br/>
#
# 2. Please explain the risk-neutral pricing of a financial asset.
# <br/>
#
# 3. How many free parameters does the binomial tree model introduce and how are these free parameters eliminated ?
# <br/>
#
# 4. If a company's hazard function is linearly increasing in time, then what is the probability of its default over time ?
# <br/>
#
# 5. What is the $\,\alpha\,$ of a portfolio ?
# <br/>
#
# 6. The `bond yield` is that particular constant zero coupon rate that makes the sum of the PVs of the bond's future cash flows equal to the current market price. A $\,2Y\,$ bond with $\,5\%\,$ coupon rate has a market value of $\,94\,$ when issued. Recall the conventions: quoted rates and coupon payment are semi-annual, face value is $\,100\,$.
#     1. What is the bond's yield ?
#     2. What is the bond's yield if it sells at par when issued ?  (par means face value)
# <br/>
# <br/>
#
# 7. Which do you think is usually more expensive ?
#   1. On Apr-22 Alice pays and **receives** from Bob $10^6$ cubic meters of natural gas **and** stores it until Oct-22.
#   2. On Apr-22 Alice pays the PV of the predicted Oct-22 price, and on Oct-22 she receives the $10^6$ cubic meters of natural gas.
# <br/>

# %% [markdown]
# ### Apr-15
#
# * If a company's probability of default from now until $\,t\,$ years from now is $\,1-e^{\,-\,t}\,$, then what is the company's default intensity ? In other words, what is the hazard function ?
# <br/>
#
# * Assume that in both of the next $\,T=2\,$ years the value of a stock will increase by $\,10\%\,$ with probability $\,p=0.6\,$ and decrease by $\,10\%\,$ with probability $\,0.4\,$.
#     - The stock's spot price is $\,S_0=100\,$. After the 2 steps what will be the 3 possible final states of $\,S_T\,$ and what probabilities will these values have ?
#     - The risk-free rate is $\,4\%\,$. What is the fair value of the ATM (At-The-Money: strike=spot) call ?
#     - What is the fair value of the ATM put ?
# <br/><br/>
#
# * Explain the difference between the Capital Allocation Line, the Capital Market Line and the Security Market Line.
# <br/>
#
# * Explain the two mutual funds theorem and the one mutual fund theorem.
# <br/>
#
# * Which asset class is the most liquid ?
# <br/>

# %% [markdown]
# ### Apr-08
#
# * Alice and Bob set up a contract. A **notional** of $\,100\,$ is applied but it **is not exchanged**. On this notional Alice pays to Bob the following **simple rates**: $\,2\%\,$ at $\,6m\,$ , $\,4\%\,$ at $\,1y\,$, $\,6\%\,$ at $\,18m\,$ and $\,8\%\,$ at $\,24m\,$. What is the equivalent constant $\,L\left(\,2\,\right)\,$ simple rate that Bob should pay **only at** $\,24m\,$ to Alice to make this a fair contract ?
# <br/>
#
# * Consider a put option on a stock with spot $\,S_0 = 100\,$, tenor $\,T = 2\,$ and strike $\,K = 50\,$. The risk-free rate is a constant $\,r=5\%\,$. If you think that $\,S_T = 108\,$ and $\,S_T = 94\,$ will happen with equal $\,0.5\,$ probabilities, then what is the current fair value of the put option ?
# <br/>
#
# * Consider a portfolio containing one call option and one put option. How can this portfolio have a V-shaped payoff ?
# <br/>
#
# * What is idiosyncratic risk ?

# %% [markdown]
# ### Mar-25
#
# * What is the relationship of the probability of default and the default intensity ?
#
# * What is the main result of the Modern Portfolio Theory ?
#
# * How do the MPT and the CAPM quantify risk ?
#
# * What is Jensen's alpha ?
#
# * Explain in one short sentence what are commodities.
#
# * What does "small cap stock" mean ?

# %% [markdown]
# ### Mar-18
#
# * Knowing the simple rate, $\,L\left(\,t\,\right)\,$, please derive the short rate, $\,r\left(\,t\,\right)\,$.
#
# * If the discount factor from $\,10Y\,$ to now is $\,0.4\,$, then what is the constant continuously compounded rate ?
#
# * Please explain the Efficient Markets Hypothesis.
#
# * What is the difference between the Sharpe ratio and the Sortino ratio ?
#
# * What is the difference between the Modern Portfolio Theory and the Capital Asset Pricing Model ?
#
# * What is the Security Market Line ?
#
# * Out of stocks and bonds, which one represents ownership and which is a debt instrument ?

# %% [markdown]
# ### Mar-11
#
# * If you know the forward rates $\,\displaystyle{F\left(\frac{1}{4},\frac{1}{2}\right)}\,$ and $\,\displaystyle{F\left(\frac{1}{2},\frac{3}{4}\right)}\,$, then what is the discount factor $\,\displaystyle{P\left(\frac{1}{4},\frac{3}{4}\right)}\,$ ?
#
# * What are the major differences between LIBOR and SOFR ?
#
# * What is arbitrage ?
#
# * Please write down the equations of the MPT.
#
# * What is the definition of $\,\beta\,$ ?

# %% [markdown]
# ### Mar-04
#
# * If you know the 1M $\rightarrow$ 2M and the 2M $\rightarrow$ 3M forward rates, and the discount factor for 3M, then what is the 1M simple rate ?
#
# * What is the hazard rate ?
#
# * What does the MPT calculate ?
#
# * What is the two mutual fund theorem ?

# %% [markdown]
# ### Feb-26
#
# * Convert the continously compounded rate to the equivalent quarterly compounded rate.
#
# * If the hazard rate is constant, then what is the probability of default as a function of time ?
#
# * What is arbitrage, and what is the Efficient Markets Hypothesis ?

# %% [markdown]
# ### Feb-19
#
#
# * Please write down the `definition` of the `present value` (PV) of a future cash flow in 1 or 2 full sentences.
#
# * What is the difference between an `instantaneous` rate and a `forward` rate ?
#
# * If you know the 4M $\rightarrow$ 5M and the 5M $\rightarrow$ 6M forward rates, and the simple rate for 6M, then what is the 4M `discount factor` ?

# %% [markdown]
# ## Spring 2022

# %%
from numpy import random
N = 10
my_list = [x for x in range(N)]
random.shuffle(my_list)
print(my_list)
# Out:
# [8, 4, 0, 6, 3, 1, 7, 5, 2, 9]

# %% [markdown]
# ### May-23
#
# 1. If the quarterly forward rate is known for each starting date, then what is the 1Y discount factor ?
#
# 2. What is the difference between the short rate and the instantaneous forward rate ?
#
# 3. What is the difference between the two mutual fund theorem and the one mutual fund theorem ?
#
# 4. Define and calculate the three parameters of the 1-step binomial tree.
#
# 5. Define the differential form of the Ito process and show the modeled underlier's rate of change in this definition.
#
# 6. Calculate the vega (also called $\,\kappa$) of the Black-Scholes-Merton price of a call option (eur, no dividends).
#
# 7. Calculate the $\,\rho\,$ of the Black-Scholes-Merton price of a call option (eur, no divid).
#
# 8. Explain the relationship between a self-financing portfolio and hedging (for example, delta hedging).

# %% [markdown]
# ### May-16
#
# * If the 2y discount factor is $\,P\left(\,0,\,2\,\right)\,$, then what is the equivalent simple rate ?
# * If the current yield curve is $\,Y\left(\,t\,\right)\,$, then what is the PV of 20 payments, each 1 unit of currency, paid at 1, 2, $\,\dots\,$, 20 years from now ?
# * If the yield curve is flat, then what is the instantaneous forward rate ?
# * If the continuous rate is $\,r\left(\,t\,\right)\,$, then what is the 3-year discount factor ?
# * What is the difference between the parabolic EF and the hyperbolic EF of the MPT ?
# * Is there a lower bound on the risk-free return in the MPT ?
# * How do you apply the MPT to portfolio selection ?
# * What is the main difference between the MPT and the CAPM ?
# * What is the difference between the CML and the SML ?
# * How do you determine the value of an asset based on its position relative to the SML ?
# * Calculate a call option's $\,\Theta\,$ from its Black-Scholes-Merton price.
# * Which one has a higher excess kurtosis: the uniform distribution or a triangular distribution ?

# %% [markdown]
# ### May-09
#
# * How does the price of a call option change (European call option a non-dividend-paying underlying stock),
# <br/>
# if the spot of the underlying stock and the strike are multiplied by the same number ?
# <br/>
# Help: use the Black-Scholes formula for the price of the call option.
#
#
# * Based on the price of a European call option and the put-call parity,
# <br/>
# calculate the price of a European put option with the same parameters.
# <br/>
# Help: use the Black-Scholes call option price, the forward price and the put-call parity.
#
#
# * Consider the function $\,N\left(x\right)\,$ in the Black-Scholes price of the call option. What is the function $\,N'\!\left(x\right)\,$?
#
#
# * Define the unconditional probability of default, the conditional probability of default,
# <br/>
# the conditional rate of default, and the default intensity function (also called hazard rate).
#
#
# * What are the three parameters of the binomial tree model and how are they determined ?

# %% [markdown]
# ### May-02
#
#
# * If you know the CDF, then what is the PDF ?
#
#
# * What is the difference between self-similar and self-affine ?
#
#
# * What is the Hurst exponent ?
#
#
# * Please name the coefficient of $\,dt\,$ and the coefficient of $\,dz\,$ that are used to define the Ito process.
#
#
# * What are the two choices at a node when pricing an American option with the binomial tree ?
#
#
# * What property of the Security Market Line is the market risk premium ?

# %% [markdown]
# ### Apr-25
#
# * Explain how a growing volatility of the underlier with a positive risk-free rate changes the value of the call option.
#
#
# * If the risk-free rate is $\,r<0\,$ and the volatility is $\,\sigma\gg |r|\,$, then how does time to maturity influence the value of a call option ?
#
#
# * How does volatility change the value of a portolio containing an ATM put + an ATM call (same underlier and maturity) ?<br/>By the way, you're analyzing a [straddle](https://www.investopedia.com/terms/s/straddle.asp).
#
#
# * Which part of the underlier's daily log increment distribution affects a deep out of the money option's value ?
#
#
# * Prove that the `expected squared displacement`, $\,\big<\left(\sum_{i=1}^N x_i\right)^2\big>\,$, of the symmetric $\,x_i=\pm 1\,$ random walk is $\,N\,$.
#   * Note that taking the square root of this result gives for the root-mean-squared distance $\,\sqrt{<r^2>\,}=\sqrt{N\,}\,$.

# %% [markdown]
# ### Apr-11
#
# * What is the difference between the Sharpe ratio and the Sortino ratio ?
#
# * What is the difference between the risk-neutral pricing and a risk-free asset ?
#
# * If the current yield curve is a linear decreasing function, then
#
#   * What is the short rate as a function of time ?
#   * What does this mean (approximately) for the economy in general ?
#
# * If the annualized percent yield is $\,7\%\,$, then what is the Fair Value of an asset that will have 1 unit value 4.5 months from now ?
#
# * Explain graphically the put-call parity. Assume that the equality does not hold -- there is arbitrage -- and use this arbitrage.

# %% [markdown]
# ### Apr-04
#
# * Please define $\,\alpha\,$ and $\,\beta\,$, and explain them graphically, too.
#
# * How is risk quantified in the MPT and the CAPM ?
#
# * What is the two mutual fund theorem ?
#
# * What are the two types of Efficient Frontier discussed by the MPT ?
#
# * Please define the Lagrange method.
#
# * If the survival function decreases linearly, then what is the hazard function ?

# %% [markdown]
# ### Mar-28
#
# * If the annualized rate with monthly compounding is $\,6\%\,$, then what is the annualized percent yield ?
#
# * With a constant forward rate $\,f\left(\,t\,\right)=f_0\,$ what is the 1-year discount factor ?
#
# * With a constant hazard function $\,h\left(\,t\,\right)=h_0\,$ what is the 1-year probability of survival ?
#
# * Knowing $\,f_0\,$ and $\,h_0\,$, what is the expectation value of the amount you receive at 6M for 1 unit invested now ?
#
# * What is the key difference between the MPT and the CAPM ?

# %% [markdown]
# ### Mar-21
#
# * If you know the 1M$\rightarrow$2M forward rate and the 2M$\rightarrow$3M forward rate, and the simple rate for 3M, then what is the 1M discount factor ?
#
# * What is the functional form of the efficient frontier of risky assets on the expected return vs. variance plane ?
#
# * What is the difference between the instantaneous spot rate and the short rate ?
#
# * Define the instantaneous forward rate using the discount factor.
#
# * If the quoted rate (with semi-annual compounding) is $\,11\%\,$, then what is the annualized percent yield ?

# %% [markdown]
# ### Mar-07
#
# * What is the difference between the conditional and the (unconditional) probability of default ?
#
# * What is the $\,\Delta t\to 0\,$ limiting case of the conditional rate of default ?
#
# * Which assumptions is the Efficient Markets Hypothesis (EMH) built on ?
#
# * Which two quantities are connected by the Modern Portfolio Theory (MPT) ?
#
# * On the plane of these two quantities what is the shape of the Efficient Frontier of risky assets ?

# %% [markdown]
# ### Feb-28
#
# * Write down the **definition of the forward rate** compactly using both text and mathematical symbols.
#
# * What is the difference between `short rate` and `spot rate` ?
#
# * If the **constant short rate** is $\,r\,$ then what is the equivalent **quarterly compounded 1 year** rate ?

# %% [markdown]
# ### Feb-20
#
# * Please write down the **definition of the discount factor** in 1 or 2 sentences using both text (human words) and mathematical symbols.
#
# * What is the difference between `spot` and `instantaneous` ?
#
# * If you know the 3M$\rightarrow$6M and the 6M$\rightarrow$1Y forward rates, and the simple rate for 1Y, then what is the 3M discount factor ?
